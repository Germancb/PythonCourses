# %% [markdown]
# # %%  Multiple tables and sql to join
# # %% python machine learning examples multiple tables sql use

# %%
# %% import libaries
import pandas as pd
from sqlalchemy import create_engine
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# %% . Connect to the Database

DATABASE_URL = f"mysql+pymysql://root:{'Crvinoah&79'}@localhost/housing_db"
#ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'Crvinoah&79'; # 'your_password';
# -- Refresh permissions
# FLUSH PRIVILEGES;
engine = create_engine(DATABASE_URL)

import urllib.parse
# password = urllib.parse.quote_plus("Crvinoah&79")    #("pass@word123") # Encodes '@' to '%40'
# DATABASE_URL = f"mysql+pymysql://root:{password}@localhost/housing_db"
# ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'Crvinoah&79'; # 'your_password';

# -- Refresh permissions
# FLUSH PRIVILEGES;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 DATABASE_URL = f"mysql+pymysql://root:{'Crvinoah&79'}@localhost/housing_db"
#       4 #ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'Crvinoah&79'; # 'your_password';
#       5 # -- Refresh permissions
#       6 # FLUSH PRIVILEGES;
# ----> 7 engine = create_engine(DATABASE_URL)
#       9 import urllib.parse
#      10 # password = urllib.parse.quote_plus("Crvinoah&79")    #("pass@word123") # Encodes '@' to '%40'
#      11 # DATABASE_URL = f"mysql+pymysql://root:{password}@localhost/housing_db"
#      12 # ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'Crvinoah&79'; # 'your_password';
#      13
#      14 # -- Refresh permissions
#      15 # FLUSH PRIVILEGES;
#
# NameError: name 'create_engine' is not defined

# %%
# %% 
sql_query = """
SELECT 
    h.SquareFootage, 
    h.Bedrooms, 
    n.AverageIncome, 
    h.SalePrice 
FROM 
    Houses h
INNER JOIN 
    Neighborhoods n ON h.NeighborhoodID = n.NeighborhoodID;
"""
df = pd.read_sql(sql_query, engine)
print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:3297, in Engine.raw_connection(self)
#    3276 """Return a "raw" DBAPI connection from the connection pool.
#    3277
#    3278 The returned object is a proxied version of the DBAPI
#    (...)   3295
#    3296 """
# -> 3297 return self.pool.connect()
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
# ...

# %%
# %%
try:
    import cryptography
    import pymysql
    print(f"Cryptography Version: {cryptography.__version__}")
    print(f"PyMySQL Version: {pymysql.__version__}")
    print("Libraries are correctly installed and visible!")
except ImportError as e:
    print(f"Library missing in this environment: {e}")
# Out:
# Cryptography Version: 46.0.3
# PyMySQL Version: 1.4.6
# Libraries are correctly installed and visible!

# %%
# %%!
ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'Crvinoah&79';
FLUSH PRIVILEGES;
# Out:
#   Cell In[15], line 2
#     ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'Crvinoah&79';
#           ^
# SyntaxError: invalid syntax

# %%
# %% cargar datos
from sqlalchemy import create_engine, text
import pandas as pd
# -- Replace 'root' with your username and 'your_password' with your actual password
# ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'Crvinoah&79'; # 'your_password';

# -- Refresh permissions
# FLUSH PRIVILEGES;

# The 'ssl_disabled' and 'plugin' settings can bypass the crypto check
engine = create_engine(
    DATABASE_URL,
    connect_args={
        "ssl_disabled": True
    }
)

try:
    with engine.connect() as conn:
        df = pd.read_sql(text("SELECT * FROM houses"), conn)
        print("Successfully loaded data!")
        print(df.head())
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connection failed: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
