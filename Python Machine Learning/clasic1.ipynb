# %%
#importing the packages to read the sql file

import os

os.listdir('/kaggle/input/classicmodels')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 7
#       4 import sqlite3
#       5 import pandas as pd
# ----> 7 con = sqlite3.connect('/kaggle/input/classicmodels/classicmodels.db')
#       8 df = pd.read_sql_query("SELECT * FROM products", con)
#       9 df.head()
#
# OperationalError: unable to open database file

# %%
#connecting to sql database and view first 5 rows in orders table

con = sqlite3.connect('/kaggle/input/classicmodels/classic.db')
pd.read_sql_query("""SELECT * FROM products""", con)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 3
#       1 #connecting to sql database and view first 5 rows in orders table
# ----> 3 con = sqlite3.connect('/kaggle/input/classicmodels/classic.db')
#       4 pd.read_sql_query("""SELECT * FROM products""", con)
#
# OperationalError: unable to open database file
