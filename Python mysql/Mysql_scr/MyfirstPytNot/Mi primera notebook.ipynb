# %% [markdown]
# # Mi primera Notebook

# %% [markdown]
# # Seccion 1

# %%
msg = ("Hola Mundo")
print(msg)

# %% [markdown]
# # Seccion 2

# %%
print("esta es la seccion 2")

# %% [markdown]
# # Seccion 3

# %%
print("Esta es la seccion tres")
